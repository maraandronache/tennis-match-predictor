# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tennis = pd.read_csv('/Users/rarescostinescu/Downloads/archive/tennis_atp/atp_matches_2024.csv')

# %%
tennis['l_SvGms'].value_counts().plot(kind='bar')
plt.show()

# %%
tennis['diff_rank'] = tennis['winner_rank'] + tennis['loser_rank']
tennis.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2024-0339     Brisbane    Hard         32             A      20240101
# 1  2024-0339     Brisbane    Hard         32             A      20240101
# 2  2024-0339     Brisbane    Hard         32             A      20240101
# 3  2024-0339     Brisbane    Hard         32             A      20240101
# 4  2024-0339     Brisbane    Hard         32             A      20240101
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        300     105777           2          NaN  ...     44.0     16.0
# 1        299     208029           1          NaN  ...     31.0     10.0
# 2        298     105777           2          NaN  ...     24.0     14.0
# 3        297     208029           1          NaN  ...     31.0     16.0
# 4        296     126128         NaN          NaN  ...     27.0     16.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# ...

# %%
tennis.corr(numeric_only=True)
# Out:
#                     draw_size  tourney_date  match_num  winner_id  winner_ht  \
# draw_size            1.000000      0.282043   0.031488  -0.010873   0.151712
# tourney_date         0.282043      1.000000   0.236730  -0.032552   0.025205
# match_num            0.031488      0.236730   1.000000  -0.078520   0.060677
# winner_id           -0.010873     -0.032552  -0.078520   1.000000  -0.229381
# winner_ht            0.151712      0.025205   0.060677  -0.229381   1.000000
# winner_age          -0.019973      0.034864   0.047335  -0.808686   0.034477
# loser_id            -0.031813      0.004819  -0.078816  -0.019615   0.008756
# loser_ht             0.038264     -0.011507   0.005713   0.026309   0.064625
# loser_age           -0.008291      0.006130   0.030833   0.020843  -0.002475
# best_of              0.407143     -0.401625  -0.296365   0.025672   0.076938
# minutes              0.206284     -0.166866  -0.093321  -0.043420   0.052471
# ...
