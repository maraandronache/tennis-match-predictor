# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Reading

# %% [markdown]
# Loading all CSV files

# %%
def load_csvs(folder="data/raw", pattern="*.csv"):
    """Load all CSV files from a specified folder into a dictionary of DataFrames."""
    data_path = Path(folder)
    csv_files = data_path.glob(pattern)
    
    data_frames = {}
    for csv_file in csv_files:
        df_name = csv_file.stem  # Use the file name without extension as the key
        data_frames[df_name] = pd.read_csv(csv_file)
    
    return data_frames

data_dict = load_csvs()
print(f"Loaded {len(data_dict)} files.")
# Out:
# Loaded 49 files.

# %% [markdown]
# Quick overview

# %%
df = data_dict.get("atp_matches_2024")

name = "atp_matches_2024"
print(f"\n{name}")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
display(df.head())
display(df.info())
display(df.describe())

# missing values 

missing = df.isna().mean().sort_values(ascending=False)
missing = missing[missing > 0] 
display(missing)

plt.figure(figsize=(10, 5))
sns.barplot(x=missing.index, y=missing.values)
plt.xticks(rotation=90)
plt.title("Missing values per column")


# examples of numerical distribution
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
relevant_num = [c for c in num_cols if c.lower() in ["minutes", "w_ace", "l_ace", "w_df", "l_df", "w_svpt", "l_svpt"]]

for col in relevant_num:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col].dropna(), bins=30, kde=True)
    plt.title(f"{name} - Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()
    
# examples of categorical distribution
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()
relevant_cat = [c for c in cat_cols if c.lower() in ["surface", "round", "tourney_name", "tourney_level"]]

if not relevant_cat:
    relevant_cat = cat_cols[:3]

for col in relevant_cat:
    vc = df[col].value_counts().head(10)
    plt.figure(figsize=(8, 4))
    sns.barplot(x=vc.index, y=vc.values)
    plt.title(f"{name} - {col} distribution (top 10)")
    plt.xticks(rotation=30, ha="right")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()
# Out:
# atp_matches_2024
# Rows: 1417, Columns: 49
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2024-0339     Brisbane    Hard         32             A      20240101
# 1  2024-0339     Brisbane    Hard         32             A      20240101
# 2  2024-0339     Brisbane    Hard         32             A      20240101
# 3  2024-0339     Brisbane    Hard         32             A      20240101
# 4  2024-0339     Brisbane    Hard         32             A      20240101
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     105777           2          NaN  ...    58.0     44.0
# 1        299     208029           1          NaN  ...    35.0     31.0
# 2        298     105777           2          NaN  ...    39.0     24.0
# 3        297     208029           1          NaN  ...    51.0     31.0
# 4        296     126128         NaN          NaN  ...    37.0     27.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# 0      16.0    11.0        8.0        9.0        14.0             2570.0
# 1      10.0    11.0        5.0        7.0         8.0             3660.0
# 2      14.0    10.0        5.0        7.0        14.0             2570.0
# 3      16.0    10.0        3.0        5.0         8.0             3660.0
# 4      16.0    10.0        5.0        8.0        39.0             1122.0
#
#   loser_rank loser_rank_points
# 0        8.0            3660.0
# 1       39.0            1122.0
# 2       55.0             902.0
# 3      116.0             573.0
# 4       44.0            1021.0
#
# [5 rows x 49 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          1417 non-null   object
#  1   tourney_name        1417 non-null   object
#  2   surface             1417 non-null   object
#  3   draw_size           1417 non-null   int64
#  4   tourney_level       1417 non-null   object
#  5   tourney_date        1417 non-null   int64
#  6   match_num           1417 non-null   int64
#  7   winner_id           1417 non-null   int64
#  8   winner_seed         618 non-null    object
#  9   winner_entry        200 non-null    object
#  10  winner_name         1417 non-null   object
#  11  winner_hand         1417 non-null   object
#  12  winner_ht           1224 non-null   float64
#  13  winner_ioc          1417 non-null   object
#  14  winner_age          1416 non-null   float64
#  15  loser_id            1417 non-null   int64
#  16  loser_seed          377 non-null    object
#  17  loser_entry         303 non-null    object
#  18  loser_name          1417 non-null   object
#  19  loser_hand          1417 non-null   object
#  20  loser_ht            1171 non-null   float64
#  21  loser_ioc           1417 non-null   object
#  22  loser_age           1414 non-null   float64
#  23  score               1417 non-null   object
#  24  best_of             1417 non-null   int64
#  25  round               1417 non-null   object
#  26  minutes             1415 non-null   float64
#  27  w_ace               1408 non-null   float64
#  28  w_df                1408 non-null   float64
#  29  w_svpt              1408 non-null   float64
#  30  w_1stIn             1408 non-null   float64
#  31  w_1stWon            1408 non-null   float64
#  32  w_2ndWon            1408 non-null   float64
#  33  w_SvGms             1408 non-null   float64
#  34  w_bpSaved           1408 non-null   float64
#  35  w_bpFaced           1408 non-null   float64
#  36  l_ace               1408 non-null   float64
#  37  l_df                1408 non-null   float64
#  38  l_svpt              1408 non-null   float64
#  39  l_1stIn             1408 non-null   float64
#  40  l_1stWon            1408 non-null   float64
#  41  l_2ndWon            1408 non-null   float64
#  42  l_SvGms             1408 non-null   float64
#  43  l_bpSaved           1408 non-null   float64
#  44  l_bpFaced           1408 non-null   float64
#  45  winner_rank         1407 non-null   float64
#  46  winner_rank_points  1407 non-null   float64
#  47  loser_rank          1392 non-null   float64
#  48  loser_rank_points   1392 non-null   float64
# dtypes: float64(27), int64(6), object(16)
# memory usage: 542.6+ KB
# None
#          draw_size  tourney_date    match_num      winner_id    winner_ht  \
# count  1417.000000  1.417000e+03  1417.000000    1417.000000  1224.000000
# mean     66.132675  2.024028e+07   240.472124  154249.505999   187.517974
# std      47.695176  1.313499e+02    82.050062   44420.535538     6.139134
# min       4.000000  2.024010e+07     1.000000  100644.000000   170.000000
# 25%      32.000000  2.024020e+07   231.000000  111442.000000   183.000000
# 50%      32.000000  2.024023e+07   276.000000  132686.000000   188.000000
# 75%     128.000000  2.024041e+07   289.000000  206173.000000   193.000000
# max     128.000000  2.024052e+07   300.000000  212721.000000   201.000000
#
#         winner_age       loser_id     loser_ht    loser_age      best_of  ...  \
# count  1416.000000    1417.000000  1171.000000  1414.000000  1417.000000  ...
# mean     26.343220  152418.196895   186.785653    26.776238     3.179252  ...
# std       4.207402   44401.523606     6.099685     4.429594     0.571492  ...
# min      17.400000  100644.000000   170.000000    16.400000     3.000000  ...
# 25%      23.275000  106432.000000   183.000000    23.600000     3.000000  ...
# 50%      26.100000  128034.000000   185.000000    26.600000     3.000000  ...
# 75%      28.200000  206173.000000   191.000000    28.775000     3.000000  ...
# max      39.600000  212722.000000   201.000000    43.900000     5.000000  ...
#
#            l_1stIn     l_1stWon     l_2ndWon      l_SvGms    l_bpSaved  \
# count  1408.000000  1408.000000  1408.000000  1408.000000  1408.000000
# mean     48.247869    32.054688    13.721591    11.768466     4.551847
# std      17.886845    13.579972     6.367833     3.767451     3.161403
# min       2.000000     0.000000     1.000000     1.000000     0.000000
# 25%      35.000000    22.000000     9.000000     9.000000     2.000000
# 50%      45.000000    29.000000    13.000000    11.000000     4.000000
# 75%      58.000000    40.000000    17.000000    14.000000     6.000000
# max     133.000000    99.000000    39.000000    27.000000    20.000000
#
#          l_bpFaced  winner_rank  winner_rank_points   loser_rank  \
# count  1408.000000  1407.000000         1407.000000  1392.000000
# mean      8.139205    78.985075         1842.418621   110.935345
# std       3.869285   138.863341         2021.463142   171.525540
# min       0.000000     1.000000            2.000000     1.000000
# 25%       5.000000    16.000000          707.000000    35.000000
# 50%       8.000000    46.000000         1021.000000    65.000000
# 75%      10.000000    83.000000         2117.500000   108.000000
# max      25.000000  1643.000000        11245.000000  1763.000000
#
#        loser_rank_points
# count        1392.000000
# mean         1149.992098
# std          1277.736202
# min             1.000000
# 25%           578.750000
# 50%           833.500000
# 75%          1191.500000
# max         11245.000000
#
# [8 rows x 33 columns]
# winner_entry          0.858857
# loser_entry           0.786168
# loser_seed            0.733945
# winner_seed           0.563867
# loser_ht              0.173606
# winner_ht             0.136203
# loser_rank            0.017643
# loser_rank_points     0.017643
# winner_rank_points    0.007057
# winner_rank           0.007057
# w_svpt                0.006351
# w_df                  0.006351
# w_ace                 0.006351
# l_ace                 0.006351
# w_2ndWon              0.006351
# w_SvGms               0.006351
# w_bpSaved             0.006351
# w_bpFaced             0.006351
# l_svpt                0.006351
# l_df                  0.006351
# w_1stWon              0.006351
# l_1stIn               0.006351
# l_1stWon              0.006351
# l_2ndWon              0.006351
# l_SvGms               0.006351
# l_bpSaved             0.006351
# l_bpFaced             0.006351
# w_1stIn               0.006351
# loser_age             0.002117
# minutes               0.001411
# winner_age            0.000706
# dtype: float64

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Deleting rows

# %%
df.drop(columns=["winner_age", "loser_age", "tourney_name", "tourney_id", "match_num", "winner_ioc", "loser_ioc", "winner_entry", "loser_entry", "winner_rank_points", "loser_rank_points", "winner_seed", "loser_seed", "tourney_level", "tourney_date", "winner_ht", "loser_ht"], inplace=True, errors='ignore')
df = df.dropna(subset=['winner_rank', 'loser_rank', 'minutes'])

# %% [markdown]
# Filter out irrelevant matches

# %%
df = df[~df['score'].str.contains('W/O|RET', case=False, na=False)]

# %%
name = "atp_matches_2024"
print(f"\n{name}")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")
display(df.head())
display(df.info())
display(df.describe())
# Out:
# atp_matches_2024
# Rows: 1347, Columns: 32
#   surface  draw_size  winner_id      winner_name winner_hand  loser_id  \
# 0    Hard         32     105777  Grigor Dimitrov           R    208029
# 1    Hard         32     208029      Holger Rune           R    126128
# 2    Hard         32     105777  Grigor Dimitrov           R    111442
# 3    Hard         32     208029      Holger Rune           R    105902
# 4    Hard         32     126128  Roman Safiullin           R    208286
#
#         loser_name loser_hand       score  best_of  ... l_df  l_svpt  l_1stIn  \
# 0      Holger Rune          R  7-6(5) 6-4        3  ...  3.0    95.0     58.0
# 1  Roman Safiullin          R  6-4 7-6(0)        3  ...  5.0    66.0     35.0
# 2  Jordan Thompson          R     6-3 7-5        3  ...  1.0    62.0     39.0
# 3  James Duckworth          R  6-2 7-6(6)        3  ...  2.0    77.0     51.0
# 4   Matteo Arnaldi          R  7-6(4) 6-2        3  ...  2.0    69.0     37.0
#
#    l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  winner_rank  loser_rank
# 0      44.0      16.0     11.0        8.0        9.0         14.0         8.0
# 1      31.0      10.0     11.0        5.0        7.0          8.0        39.0
# 2      24.0      14.0     10.0        5.0        7.0         14.0        55.0
# 3      31.0      16.0     10.0        3.0        5.0          8.0       116.0
# 4      27.0      16.0     10.0        5.0        8.0         39.0        44.0
#
# [5 rows x 32 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 1347 entries, 0 to 1415
# Data columns (total 32 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   surface      1347 non-null   object
#  1   draw_size    1347 non-null   int64
#  2   winner_id    1347 non-null   int64
#  3   winner_name  1347 non-null   object
#  4   winner_hand  1347 non-null   object
#  5   loser_id     1347 non-null   int64
#  6   loser_name   1347 non-null   object
#  7   loser_hand   1347 non-null   object
#  8   score        1347 non-null   object
#  9   best_of      1347 non-null   int64
#  10  round        1347 non-null   object
#  11  minutes      1347 non-null   float64
#  12  w_ace        1347 non-null   float64
#  13  w_df         1347 non-null   float64
#  14  w_svpt       1347 non-null   float64
#  15  w_1stIn      1347 non-null   float64
#  16  w_1stWon     1347 non-null   float64
#  17  w_2ndWon     1347 non-null   float64
#  18  w_SvGms      1347 non-null   float64
#  19  w_bpSaved    1347 non-null   float64
#  20  w_bpFaced    1347 non-null   float64
#  21  l_ace        1347 non-null   float64
#  22  l_df         1347 non-null   float64
#  23  l_svpt       1347 non-null   float64
#  24  l_1stIn      1347 non-null   float64
#  25  l_1stWon     1347 non-null   float64
#  26  l_2ndWon     1347 non-null   float64
#  27  l_SvGms      1347 non-null   float64
#  28  l_bpSaved    1347 non-null   float64
#  29  l_bpFaced    1347 non-null   float64
#  30  winner_rank  1347 non-null   float64
#  31  loser_rank   1347 non-null   float64
# dtypes: float64(21), int64(4), object(7)
# memory usage: 347.3+ KB
# None
#          draw_size      winner_id       loser_id      best_of      minutes  \
# count  1347.000000    1347.000000    1347.000000  1347.000000  1347.000000
# mean     67.309577  153837.769859  151689.042316     3.181143   117.156644
# std      47.515399   44349.137897   44157.869038     0.574211    40.585572
# min       4.000000  100644.000000  100644.000000     3.000000    43.000000
# 25%      32.000000  111442.000000  106432.000000     3.000000    87.000000
# 50%      32.000000  132686.000000  127760.000000     3.000000   109.000000
# 75%     128.000000  206173.000000  205734.000000     3.000000   141.000000
# max     128.000000  212051.000000  212203.000000     5.000000   299.000000
#
#              w_ace         w_df       w_svpt      w_1stIn     w_1stWon  ...  \
# count  1347.000000  1347.000000  1347.000000  1347.000000  1347.000000  ...
# mean      6.298441     2.190794    76.251670    48.473645    36.360059  ...
# std       4.798776     1.970429    26.335583    17.435592    12.533532  ...
# min       0.000000     0.000000    32.000000    18.000000    12.000000  ...
# 25%       3.000000     1.000000    56.000000    36.000000    27.000000  ...
# 50%       5.000000     2.000000    71.000000    45.000000    34.000000  ...
# 75%       9.000000     3.000000    90.000000    58.000000    42.000000  ...
# max      31.000000    13.000000   202.000000   137.000000   105.000000  ...
#
#               l_df       l_svpt      l_1stIn     l_1stWon     l_2ndWon  \
# count  1347.000000  1347.000000  1347.000000  1347.000000  1347.000000
# mean      2.744618    78.811433    48.834447    32.497402    13.886414
# std       2.167940    26.195914    17.745394    13.498025     6.362713
# min       0.000000    31.000000    17.000000     6.000000     1.000000
# 25%       1.000000    59.000000    36.000000    23.000000     9.000000
# 50%       2.000000    73.000000    46.000000    30.000000    13.000000
# 75%       4.000000    94.000000    58.000000    40.000000    17.500000
# max      14.000000   202.000000   133.000000    99.000000    39.000000
#
#            l_SvGms    l_bpSaved    l_bpFaced  winner_rank   loser_rank
# count  1347.000000  1347.000000  1347.000000  1347.000000  1347.000000
# mean     11.907944     4.598367     8.193764    75.618411   111.392725
# std       3.714414     3.167643     3.854951   131.531181   172.300304
# min       6.000000     0.000000     0.000000     1.000000     1.000000
# 25%       9.000000     2.000000     5.000000    16.000000    35.000000
# 50%      11.000000     4.000000     8.000000    46.000000    65.000000
# 75%      14.000000     6.000000    10.000000    82.000000   108.500000
# max      27.000000    20.000000    25.000000  1643.000000  1763.000000
#
# [8 rows x 25 columns]
